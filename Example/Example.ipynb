# %%
from Radio_cube_utilities import Radio_cube_utilities

# %%
file = Radio_cube_utilities("/Users/fairymath/Desktop/MWCentreClouds/Data/C1_HI_MKT+GBT_COregrid.fits")
file_CO = Radio_cube_utilities("/Users/fairymath/Desktop/MWCentreClouds/Data/C1_CO_APEX.fits")

# %%
file.moment_maps(0, 'HI')

# %%
file.mask_HI(4, 2)

# %%
file_CO.mask_CO(5, 30)

# %%
file.PV_plot(8.2, file_CO)

# %%
from Radio_maps import Radio_maps

# %%
file = Radio_maps("/Users/fairymath/Desktop/MWCentreClouds/Data/C1_HI_MKT+GBT_COregrid_masked4_m0.fits", 8.2)
file_CO = Radio_maps("/Users/fairymath/Desktop/MWCentreClouds/Data/C1_CO_APEX_masked5_m0.fits", 8.2)
file_nm = Radio_maps("/Users/fairymath/Desktop/MWCentreClouds/Data/C1_CO_APEX_noisemap.fits", 8.2)

# %%
file.column_density_map('HI')

# %%
file_CO.column_density_map('CO')

# %%
file.overlays(file_CO)

# %%
file.mass(1)
# Out:
# Mass: 320.594 Msun

# %%
file_CO.mass(2)
# Out:
# Mass: 811.576 Msun

# %%
file.hist(file_CO)

# %%
file.SD_scatter(file_CO, file_nm, 5)

# %%
file.mol_frac_maps(file_CO, file_nm, 5)
